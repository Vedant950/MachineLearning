# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# Fitting the best fit decision tree regression model on the dataset Position Vs Salary and predict the salary of the employees based on the position level in the organization.

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Data_set/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
Y = dataset.iloc[:, 2].values

# %% [markdown]
# ### Fitting the dataset

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg.fit(X, Y)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Visualizing the dataset

# %%
plt.figure(figsize = (12, 8))
plt.scatter(X, Y, color = 'red', marker = 'x')
plt.title('Position Vs Salary')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Visualizing the model

# %%
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid),1))
plt.figure(figsize = (12, 8))
plt.scatter(X, Y, color = 'red', marker = 'x')
plt.plot(X_grid, reg.predict(X_grid))
plt.title('Position Vs Salary')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
